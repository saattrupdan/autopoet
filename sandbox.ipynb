# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('tweets.tsv', sep = '\t')
df.head()
# Out:
#                                                tweet  count
# 0                            I AM DRAINING THE SWAMP      6
# 1                            https://t.co/U7WxKrO6Kx     21
# 2  If that perfect phone call with the President ...     24
# 3  then no future President can EVER again speak ...     21
# 4  Sounding more and more like the so-called Whis...     23

# %%
df.shape
# Out:
# (74699, 2)

# %%
df['chars'] = df['tweet'].apply(lambda x: len(x))
df.head()
# Out:
#                                                tweet  count  chars
# 0                            I AM DRAINING THE SWAMP      6     23
# 1                            https://t.co/U7WxKrO6Kx     21     23
# 2  If that perfect phone call with the President ...     24     85
# 3  then no future President can EVER again speak ...     21     71
# 4  Sounding more and more like the so-called Whis...     23     84

# %%
set(df[df['chars'] == df['count']]['tweet'].values)
# Out:
# {'#MS13',
#  '#NC03',
#  '#NY1',
#  '#Tump2016',
#  '$400000',
#  "'11",
#  '1',
#  '1/2',
#  '11.2.12',
#  '14',
#  '158000000',
#  '19',
#  '2',
#  '20',
#  '2004)',
#  '20th',
#  '21 pt',
#  '2A',
#  '3',
#  '3/14',
#  '4',
#  '4th',
#  '5K+',
#  '6',
#  '69-30',
#  '7:PM',
#  '8',
#  '8 2013)',
#  '84-8',
#  '9',
#  '9-0',
#  '@ABC',
#  '@CBP',
#  '@CBS',
#  '@CNN',
#  '@Candi2577 Great',
#  '@NBC',
#  '@SHANEDIESEL777',
#  '@TBN',
#  '@VP',
#  '@lp084',
#  '@nal53199 I will',
#  '@nbc',
#  '@nfl',
#  '@paul1994loan',
#  '@splinter48708',
#  "@thomasm25221024 I won't",
#  'A',
#  'ABC',
#  'ASAP',
#  'CBS',
#  'CEO',
#  'CNN',
#  'DC',
#  'Dr',
#  'FBI',
#  'FL',
#  'GDP',
#  'I',
#  'IA',
#  'IRS',
#  'In 2016',
#  'In 2018',
#  'In 2020',
#  'Jr',
#  'L',
#  'Lt',
#  'M',
#  'MD',
#  'MN',
#  'Mr',
#  'N',
#  'NBC',
#  'NC',
#  'NFL',
#  'NM',
#  'NV',
#  'Nov',
#  'OK',
#  'P',
#  'Ph',
#  'S',
#  'SC',
#  'Sr',
#  'TN',
#  'USA',
#  'V',
#  'VP',
#  'at 212.867.4466',
# ...

# %%
df[df['tweet']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-3d8b538af2a3> in <module>
# ----> 1 df['http' in df['tweet']]
#
# ...
